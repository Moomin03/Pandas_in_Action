# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
pd.read_csv('space_missions.csv')
# Out:
#         Date Company Name    Location    Cost   Status
# 0     2/5/19  Arianespace      France  200.00  Success
# 1    2/22/19       SpaceX         USA   50.00  Success
# 2     3/2/19       SpaceX         USA   50.00  Success
# 3     3/9/19         CASC       China   29.15  Success
# 4    3/22/19  Arianespace      France   37.00  Success
# ..       ...          ...         ...     ...      ...
# 115  7/25/20         CASC       China   64.68  Success
# 116  7/30/20          ULA         USA  145.00  Success
# 117  7/30/20    Roscosmos  Kazakhstan   65.00  Success
# 118   8/6/20         CASC       China   29.75  Success
# 119   8/7/20       SpaceX         USA   50.00  Success
#
# [120 rows x 5 columns]

# %%
space = pd.read_csv(filepath_or_buffer='space_missions.csv',
            parse_dates=['Date'],
            index_col='Date')
space.head()
# Out:
# /var/folders/yd/4k8th6097mb8w26m8__j7j140000gn/T/ipykernel_45131/3319213636.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   space = pd.read_csv(filepath_or_buffer='space_missions.csv',
#            Company Name Location    Cost   Status
# Date
# 2019-02-05  Arianespace   France  200.00  Success
# 2019-02-22       SpaceX      USA   50.00  Success
# 2019-03-02       SpaceX      USA   50.00  Success
# 2019-03-09         CASC    China   29.15  Success
# 2019-03-22  Arianespace   France   37.00  Success

# %%
space['Cost'].head()
# Out:
# Date
# 2019-02-05    200.00
# 2019-02-22     50.00
# 2019-03-02     50.00
# 2019-03-09     29.15
# 2019-03-22     37.00
# Name: Cost, dtype: float64

# %%
space['Cost'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
data = [
    [2000, 3000000],
    [5000, 5000000]
]
df = pd.DataFrame(data)
df.plot()
# Out:
# <Axes: >

# %%
space.plot(y='Cost', cmap='gray')
# Out:
# <Axes: xlabel='Date'>

# %%
plt.colormaps()
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
# ...

# %%
space.value_counts(subset=['Company Name']).plot(kind='bar')
# Out:
# <Axes: xlabel='Company Name'>

# %%
space['Company Name'].value_counts().plot(kind='barh', cmap='cool')
# Out:
# <Axes: ylabel='Company Name'>

# %%
space['Status'].value_counts()
# Out:
# Status
# Success    114
# Failure      6
# Name: count, dtype: int64

# %%
space['Status'].value_counts().plot(kind='pie', legend=True)
# Out:
# <Axes: ylabel='count'>
