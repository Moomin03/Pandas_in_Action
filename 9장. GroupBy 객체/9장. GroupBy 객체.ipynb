# %%
import pandas as pd

# %%
supermarket = pd.DataFrame({
    'item':['Banana', 'Cucumber', 'Orange', 'Tomato', 'Watermelon'],
    'Type':['Fruit', 'Vegetable', 'Fruit', 'Vegetable', 'Fruit'],
    'Price':[0.99, 1.25, 0.25, 0.33, 3.00]
})
supermarket.head()
# Out:
#          item       Type  Price
# 0      Banana      Fruit   0.99
# 1    Cucumber  Vegetable   1.25
# 2      Orange      Fruit   0.25
# 3      Tomato  Vegetable   0.33
# 4  Watermelon      Fruit   3.00

# %%
groups = supermarket.groupby('Type')
groups

# %%
groups.get_group('Fruit')
# Out:
#          item   Type  Price
# 0      Banana  Fruit   0.99
# 2      Orange  Fruit   0.25
# 4  Watermelon  Fruit   3.00

# %%
groups.get_group('Vegetable')
# Out:
#        item       Type  Price
# 1  Cucumber  Vegetable   1.25
# 3    Tomato  Vegetable   0.33

# %%
groups.mean(numeric_only=True)
# Out:
#               Price
# Type
# Fruit      1.413333
# Vegetable  0.790000

# %%
fortune = pd.read_csv('fortune1000.csv')
fortune.head()
# Out:
#               Company  Revenues  Profits  Employees       Sector  \
# 0             Walmart  500343.0   9862.0    2300000    Retailing
# 1         Exxon Mobil  244363.0  19710.0      71200       Energy
# 2  Berkshire Hathaway  242137.0  44940.0     377000   Financials
# 3               Apple  229234.0  48351.0     123000   Technology
# 4  UnitedHealth Group  201159.0  10558.0     260000  Health Care
#
#                                    Industry
# 0                     General Merchandisers
# 1                        Petroleum Refining
# 2  Insurance: Property and Casualty (Stock)
# 3               Computers, Office Equipment
# 4   Health Care: Insurance and Managed Care

# %%
fortune[fortune['Sector']=='Retailing']
# Out:
#                       Company  Revenues  Profits  Employees     Sector  \
# 0                     Walmart  500343.0   9862.0    2300000  Retailing
# 7                  Amazon.com  177866.0   3033.0     566000  Retailing
# 14                     Costco  129025.0   2679.0     182000  Retailing
# 22                 Home Depot  100904.0   8630.0     413000  Retailing
# 38                     Target   71879.0   2934.0     345000  Retailing
# ..                        ...       ...      ...        ...        ...
# 909      99 Cents Only Stores    2194.0    -90.3      17200  Retailing
# 926                   Express    2138.0     19.4       9576  Retailing
# 971               Finish Line    1934.0    -18.2       8200  Retailing
# 989  Barnes & Noble Education    1874.0      5.4      13375  Retailing
# 992           Childrens Place    1870.0     84.7       9800  Retailing
#
#                             Industry
# 0              General Merchandisers
# 7    Internet Services and Retailing
# ...

# %%
fortune[fortune['Sector']=='Retailing']['Revenues'].head()
# Out:
# 0     500343.0
# 7     177866.0
# 14    129025.0
# 22    100904.0
# 38     71879.0
# Name: Revenues, dtype: float64

# %%
fortune[fortune['Sector']=='Retailing']['Revenues'].mean()
# Out:
# np.float64(21874.714285714286)

# %%
sectors = fortune.groupby('Sector')

# %%
sectors

# %%
len(sectors)
# Out:
# 21

# %%
fortune['Sector'].nunique()
# Out:
# 21

# %%
sectors.size()
# Out:
# Sector
# Aerospace & Defense               25
# Apparel                           14
# Business Services                 53
# Chemicals                         33
# Energy                           107
# Engineering & Construction        27
# Financials                       155
# Food &  Drug Stores               12
# Food, Beverages & Tobacco         37
# Health Care                       71
# Hotels, Restaurants & Leisure     26
# Household Products                28
# Industrials                       49
# Materials                         45
# Media                             25
# Motor Vehicles & Parts            19
# Retailing                         77
# Technology                       103
# Telecommunications                10
# Transportation                    40
# Wholesalers                       44
# dtype: int64

# %%
sectors.groups
# Out:
# {'Aerospace & Defense': [26, 50, 58, 98, 117, 118, 207, 224, 275, 380, 404, 406, 414, 540, 660, 661, 806, 829, 884, 930, 954, 955, 959, 975, 988], 'Apparel': [88, 241, 331, 420, 432, 526, 529, 554, 587, 678, 766, 774, 835, 861], 'Business Services': [142, 160, 187, 199, 201, 221, 235, 242, 253, 295, 325, 358, 364, 423, 462, 465, 486, 493, 497, 499, 502, 510, 528, 567, 577, 584, 591, 599, 604, 618, 649, 686, 691, 692, 700, 702, 712, 720, 738, 744, 771, 802, 810, 825, 879, 888, 894, 895, 898, 905, 922, 972, 997], 'Chemicals': [46, 189, 190, 198, 214, 263, 281, 309, 344, 351, 381, 447, 450, 454, 527, 593, 623, 648, 671, 672, 679, 704, 722, 740, 790, 836, 865, 872, 908, 932, 958, 963, 978], 'Energy': [1, 12, 27, 30, 40, 63, 89, 90, 91, 94, 104, 114, 124, 125, 134, 145, 166, 167, 175, 184, 205, 212, 213, 217, 218, 219, 222, 231, 232, 243, 248, 254, 256, 265, 268, 269, 270, 273, 307, 313, 326, 333, 335, 343, 352, 363, 371, 379, 383, 384, 387, 428, 437, 452, 456, 488, 490, 496, 498, 500, 51
# ...

# %%
fortune.loc[26]
# Out:
# Company                     Boeing
# Revenues                   93392.0
# Profits                     8197.0
# Employees                   140800
# Sector         Aerospace & Defense
# Industry     Aerospace and Defense
# Name: 26, dtype: object

# %%
sectors.first()
# Out:
#                                               Company  Revenues  Profits  \
# Sector
# Aerospace & Defense                            Boeing   93392.0   8197.0
# Apparel                                          Nike   34350.0   4240.0
# Business Services                       ManpowerGroup   21034.0    545.4
# Chemicals                                   DowDuPont   62683.0   1460.0
# Energy                                    Exxon Mobil  244363.0  19710.0
# Engineering & Construction                      Fluor   19521.0    191.4
# Financials                         Berkshire Hathaway  242137.0  44940.0
# Food &  Drug Stores                            Kroger  122662.0   1907.0
# Food, Beverages & Tobacco                     PepsiCo   63525.0   4857.0
# Health Care                        UnitedHealth Group  201159.0  10558.0
# Hotels, Restaurants & Leisure  Marriott International   22894.0   1372.0
# Household Products                   Procter & Gamble   66217.0  15326.0
# ...

# %%
sectors.last()
# Out:
#                                                    Company  Revenues  Profits  \
# Sector
# Aerospace & Defense            Aerojet Rocketdyne Holdings    1877.0     -9.2
# Apparel                               Wolverine World Wide    2350.0      0.3
# Business Services                                CoreLogic    1851.0    152.2
# Chemicals                                           Stepan    1925.0     91.6
# Energy                            Superior Energy Services    1874.0   -205.9
# Engineering & Construction                        TopBuild    1906.0    158.1
# Financials                                             HCP    1848.0    414.2
# Food &  Drug Stores                                  Freds    2064.0   -140.3
# Food, Beverages & Tobacco                        Universal    2071.0    106.3
# Health Care                                   Ensign Group    1849.0     40.5
# Hotels, Restaurants & Leisure                 Vail Resorts    1907.0    210.6
# ...

# %%
sectors.nth(0)
# Out:
#                     Company  Revenues  Profits  Employees  \
# 0                   Walmart  500343.0   9862.0    2300000
# 1               Exxon Mobil  244363.0  19710.0      71200
# 2        Berkshire Hathaway  242137.0  44940.0     377000
# 3                     Apple  229234.0  48351.0     123000
# 4        UnitedHealth Group  201159.0  10558.0     260000
# 5                  McKesson  198533.0   5070.0      64500
# 8                      AT&T  160546.0  29450.0     254000
# 9            General Motors  157311.0  -3864.0     180000
# 16                   Kroger  122662.0   1907.0     449000
# 17         General Electric  122274.0  -5786.0     313000
# 26                   Boeing   93392.0   8197.0     140800
# 41         Procter & Gamble   66217.0  15326.0      95000
# 43                      UPS   65872.0   4910.0     346415
# 44                  PepsiCo   63525.0   4857.0     263000
# 46                DowDuPont   62683.0   1460.0      98000
# ...

# %%
sectors.nth(1)
# Out:
#                       Company  Revenues  Profits  Employees  \
# 6                  CVS Health  184765.0   6622.0     203000
# 7                  Amazon.com  177866.0   3033.0     566000
# 10                 Ford Motor  156776.0   7602.0     202000
# 11          AmerisourceBergen  153144.0    364.5      19500
# 12                    Chevron  134533.0   9195.0      51900
# 15                    Verizon  126034.0  30101.0     155400
# 18   Walgreens Boots Alliance  118214.0   4078.0     290000
# 19             JPMorgan Chase  113899.0  24441.0     252539
# 21                   Alphabet  110855.0  12662.0      80110
# 47     Archer Daniels Midland   60828.0   1595.0      31300
# 49                      FedEx   60319.0   2997.0     357000
# 50        United Technologies   59837.0   4552.0     204700
# 64                Caterpillar   45462.0    754.0      98400
# 97                Time Warner   31271.0   5247.0      26000
# 130                 McDonalds   22820.0   5192.3     235000
# ...

# %%
fortune[fortune['Sector']=='Technology']
# Out:
#                     Company  Revenues  Profits  Employees      Sector  \
# 3                     Apple  229234.0  48351.0     123000  Technology
# 21                 Alphabet  110855.0  12662.0      80110  Technology
# 29                Microsoft   89950.0  21204.0     124000  Technology
# 33                      IBM   79139.0   5753.0     397800  Technology
# 34        Dell Technologies   78660.0  -3728.0     145000  Technology
# ..                      ...       ...      ...        ...         ...
# 969  Cadence Design Systems    1943.0    204.1       7214  Technology
# 970   Nuance Communications    1939.0   -151.0      11600  Technology
# 973              ServiceNow    1933.0   -149.1       6222  Technology
# 983         MKS Instruments    1916.0    339.1       4923  Technology
# 991        VeriFone Systems    1871.0   -173.8       5600  Technology
#
#                                            Industry
# 3                       Computers, Office Equipment
# ...

# %%
sectors.head(2)
# Out:
#                       Company  Revenues  Profits  Employees  \
# 0                     Walmart  500343.0   9862.0    2300000
# 1                 Exxon Mobil  244363.0  19710.0      71200
# 2          Berkshire Hathaway  242137.0  44940.0     377000
# 3                       Apple  229234.0  48351.0     123000
# 4          UnitedHealth Group  201159.0  10558.0     260000
# 5                    McKesson  198533.0   5070.0      64500
# 6                  CVS Health  184765.0   6622.0     203000
# 7                  Amazon.com  177866.0   3033.0     566000
# 8                        AT&T  160546.0  29450.0     254000
# 9              General Motors  157311.0  -3864.0     180000
# 10                 Ford Motor  156776.0   7602.0     202000
# 11          AmerisourceBergen  153144.0    364.5      19500
# 12                    Chevron  134533.0   9195.0      51900
# 15                    Verizon  126034.0  30101.0     155400
# 16                     Kroger  122662.0   1907.0     449000
# ...

# %%
sectors.get_group('Materials')
# Out:
#                         Company  Revenues  Profits  Employees     Sector  \
# 123         International Paper   23302.0   2144.0      56000  Materials
# 150                       Nucor   20252.0   1318.7      25100  Materials
# 193                    WestRock   14860.0    708.2      44800  Materials
# 245         United States Steel   12250.0    387.0      29200  Materials
# 261                       Alcoa   11652.0    217.0      14600  Materials
# 276                        Ball   10983.0    374.0      18300  Materials
# 304   Reliance Steel & Aluminum    9721.0    613.4      14900  Materials
# 311              Steel Dynamics    9539.0    812.7       7635  Materials
# 337              Crown Holdings    8698.0    323.0      24342  Materials
# 393                Weyerhaeuser    7196.0    582.0       9300  Materials
# 398          Berry Global Group    7095.0    340.0      23000  Materials
# 399        Builders FirstSource    7034.0     38.8      15000  Materials
# ...

# %%
fortune.groupby('Sector').get_group('Materials')
# Out:
#                         Company  Revenues  Profits  Employees     Sector  \
# 123         International Paper   23302.0   2144.0      56000  Materials
# 150                       Nucor   20252.0   1318.7      25100  Materials
# 193                    WestRock   14860.0    708.2      44800  Materials
# 245         United States Steel   12250.0    387.0      29200  Materials
# 261                       Alcoa   11652.0    217.0      14600  Materials
# 276                        Ball   10983.0    374.0      18300  Materials
# 304   Reliance Steel & Aluminum    9721.0    613.4      14900  Materials
# 311              Steel Dynamics    9539.0    812.7       7635  Materials
# 337              Crown Holdings    8698.0    323.0      24342  Materials
# 393                Weyerhaeuser    7196.0    582.0       9300  Materials
# 398          Berry Global Group    7095.0    340.0      23000  Materials
# 399        Builders FirstSource    7034.0     38.8      15000  Materials
# ...

# %%
sectors['Revenues'].sum(numeric_only=True)
# Out:
# Sector
# Aerospace & Defense               383835.0
# Apparel                           101157.3
# Business Services                 316090.0
# Chemicals                         251151.0
# Energy                           1543507.2
# Engineering & Construction        172782.0
# Financials                       2442480.0
# Food &  Drug Stores               405468.0
# Food, Beverages & Tobacco         510232.0
# Health Care                      1507991.4
# Hotels, Restaurants & Leisure     179825.0
# Household Products                231779.8
# Industrials                       520140.0
# Materials                         278298.0
# Media                             230487.4
# Motor Vehicles & Parts            433535.0
# Retailing                        1684353.0
# Technology                       1374822.3
# Telecommunications                466959.0
# Transportation                    455160.0
# Wholesalers                       888149.0
# Name: Revenues, dtype: float64

# %%
sectors.get_group('Transportation').loc[:, 'Revenues'].sum()
# Out:
# np.float64(455160.0)

# %%
sectors.mean(numeric_only=True)
# Out:
#                                    Revenues      Profits      Employees
# Sector
# Aerospace & Defense            15353.400000  1069.340000   40404.960000
# Apparel                         7225.521429   453.621429   25407.071429
# Business Services               5963.962264   701.494340   30075.452830
# Chemicals                       7610.636364   620.454545   14364.242424
# Energy                         14425.300935   805.373585    9170.158879
# Engineering & Construction      6399.333333   263.740741   15583.148148
# Financials                     15757.935484  1704.861290   22581.412903
# Food &  Drug Stores            33789.000000   703.358333  116506.166667
# Food, Beverages & Tobacco      13790.054054  1483.851351   29170.702703
# Health Care                    21239.315493  1306.916901   41847.732394
# Hotels, Restaurants & Leisure   6916.346154   819.442308   88628.346154
# Household Products              8277.850000   990.242857   24103.428571
# ...

# %%
sectors['Revenues'].sum()
# Out:
# Sector
# Aerospace & Defense               383835.0
# Apparel                           101157.3
# Business Services                 316090.0
# Chemicals                         251151.0
# Energy                           1543507.2
# Engineering & Construction        172782.0
# Financials                       2442480.0
# Food &  Drug Stores               405468.0
# Food, Beverages & Tobacco         510232.0
# Health Care                      1507991.4
# Hotels, Restaurants & Leisure     179825.0
# Household Products                231779.8
# Industrials                       520140.0
# Materials                         278298.0
# Media                             230487.4
# Motor Vehicles & Parts            433535.0
# Retailing                        1684353.0
# Technology                       1374822.3
# Telecommunications                466959.0
# Transportation                    455160.0
# Wholesalers                       888149.0
# Name: Revenues, dtype: float64

# %%
aggregation = {
    'Revenues':'min',
    'Profits':'max',
    'Employees':'mean'
}
sectors.agg(func=aggregation)
# Out:
#                                Revenues  Profits      Employees
# Sector
# Aerospace & Defense              1877.0   8197.0   40404.960000
# Apparel                          2350.0   4240.0   25407.071429
# Business Services                1851.0   6699.0   30075.452830
# Chemicals                        1925.0   3000.4   14364.242424
# Energy                           1874.0  19710.0    9170.158879
# Engineering & Construction       1906.0   1038.4   15583.148148
# Financials                       1848.0  44940.0   22581.412903
# Food &  Drug Stores              2064.0   4078.0  116506.166667
# Food, Beverages & Tobacco        2071.0  10999.0   29170.702703
# Health Care                      1849.0  21308.0   41847.732394
# Hotels, Restaurants & Leisure    1907.0   5192.3   88628.346154
# Household Products               1949.0  15326.0   24103.428571
# Industrials                      1918.0   4858.0   31961.428571
# Materials                        1933.0   2144.0   14527.800000
# ...

# %%
sectors['Employees'].agg('mean')
# Out:
# Sector
# Aerospace & Defense               40404.960000
# Apparel                           25407.071429
# Business Services                 30075.452830
# Chemicals                         14364.242424
# Energy                             9170.158879
# Engineering & Construction        15583.148148
# Financials                        22581.412903
# Food &  Drug Stores              116506.166667
# Food, Beverages & Tobacco         29170.702703
# Health Care                       41847.732394
# Hotels, Restaurants & Leisure     88628.346154
# Household Products                24103.428571
# Industrials                       31961.428571
# Materials                         14527.800000
# Media                             21839.400000
# Motor Vehicles & Parts            49662.210526
# Retailing                         88320.233766
# Technology                        31036.961165
# Telecommunications                78560.900000
# Transportation                    41302.825000
# ...

# %%
fortune.nlargest(n=5, columns='Profits')
# Out:
#                Company  Revenues  Profits  Employees              Sector  \
# 3                Apple  229234.0  48351.0     123000          Technology
# 2   Berkshire Hathaway  242137.0  44940.0     377000          Financials
# 15             Verizon  126034.0  30101.0     155400  Telecommunications
# 8                 AT&T  160546.0  29450.0     254000  Telecommunications
# 19      JPMorgan Chase  113899.0  24441.0     252539          Financials
#
#                                     Industry
# 3                Computers, Office Equipment
# 2   Insurance: Property and Casualty (Stock)
# 15                        Telecommunications
# 8                         Telecommunications
# 19                          Commercial Banks

# %%
def get_largest_row(df):
    return df.nlargest(1, 'Revenues')

# %%
sectors.apply(get_largest_row)
# Out:
# /var/folders/yd/4k8th6097mb8w26m8__j7j140000gn/T/ipykernel_7808/3802245821.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sectors.apply(get_largest_row)
#                                                   Company  Revenues  Profits  \
# Sector
# Aerospace & Defense           26                   Boeing   93392.0   8197.0
# Apparel                       88                     Nike   34350.0   4240.0
# Business Services             142           ManpowerGroup   21034.0    545.4
# Chemicals                     46                DowDuPont   62683.0   1460.0
# Energy                        1               Exxon Mobil  244363.0  19710.0
# ...

# %%
sector_and_industry = fortune.groupby(by=['Sector', 'Industry'])
sector_and_industry.size()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            25
# Apparel              Apparel                                          14
# Business Services    Advertising, marketing                            2
#                      Diversified Outsourcing Services                 14
#                      Education                                         2
#                                                                       ..
# Transportation       Trucking, Truck Leasing                          11
# Wholesalers          Wholesalers: Diversified                         24
#                      Wholesalers: Electronics and Office Equipment     8
#                      Wholesalers: Food and Grocery                     6
#                      Wholesalers: Health Care                          6
# Length: 82, dtype: int64

# %%
sector_and_industry.get_group(('Business Services', 'Education'))
# Out:
#                 Company  Revenues  Profits  Employees             Sector  \
# 567  Laureate Education    4378.0     91.5      54500  Business Services
# 810     Graham Holdings    2592.0    302.0      16153  Business Services
#
#       Industry
# 567  Education
# 810  Education

# %%
sector_and_industry.sum(numeric_only=True)
# Out:
#                                                                    Revenues  \
# Sector              Industry
# Aerospace & Defense Aerospace and Defense                          383835.0
# Apparel             Apparel                                        101157.3
# Business Services   Advertising, marketing                          23156.0
#                     Diversified Outsourcing Services                74175.0
#                     Education                                        6970.0
# ...                                                                     ...
# Transportation      Trucking, Truck Leasing                         43676.0
# Wholesalers         Wholesalers: Diversified                       130984.0
#                     Wholesalers: Electronics and Office Equipment  122231.0
#                     Wholesalers: Food and Grocery                  125908.0
#                     Wholesalers: Health Care                       509026.0
#
# ...

# %%
sector_and_industry['Revenues'].mean()
# Out:
# Sector               Industry
# Aerospace & Defense  Aerospace and Defense                            15353.400000
# Apparel              Apparel                                           7225.521429
# Business Services    Advertising, marketing                           11578.000000
#                      Diversified Outsourcing Services                  5298.214286
#                      Education                                         3485.000000
#                                                                           ...
# Transportation       Trucking, Truck Leasing                           3970.545455
# Wholesalers          Wholesalers: Diversified                          5457.666667
#                      Wholesalers: Electronics and Office Equipment    15278.875000
#                      Wholesalers: Food and Grocery                    20984.666667
#                      Wholesalers: Health Care                         84837.666667
# ...
